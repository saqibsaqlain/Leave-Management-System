# %%
import matplotlib.pyplot as plt
#from matplotlib import pyplot as plt
X= ['Abhishek','SRK','aryan','sonu','kaushik']
Y= [1,6,3,9,5]
plt.plot(X,Y)
plt.xlabel("Leave Taken By Employee")
plt.ylabel("No Of Days Taken")
plt.title("Leave Management System")
plt.show()
